# %%
print('Olá, mundo!')

# %% [markdown]
# ## Aula 01 - Primeiros passos com Pandas
#
# Nesta aula vamos abrir nossa primeira base de dados.

# %%
import pandas as pd

# %%
data_frame = pd.read_csv('vendas_loja_dataset.csv')

# %%
data_frame

# %%
data_frame.head()

# %%
data_frame.tail()

# %%
data_frame.shape

# %%
data_frame.columns

# %%
data_frame.describe()
